# %%
print('Hello World!') # print string
# Out:
# Hello World!

# %%
print(2 ** 8)  # 2 raised to the power 8 in Python, print integer
# Out:
# 256

# %% [markdown]
# Use Ctrl-D (on Unix) or Ctrl-Z (on Windows) to exit

# %%
lumberjack = 'okay'
lumberjack
# Out:
# 'okay'

# %%
2 ** 8
# Out:
# 256

# %% [markdown]
#  Interactive Prompt - Experimenting

# %%
'Spam!' * 8   # * means multiply for numbers, but repeat for strings
# Out:
# 'Spam!Spam!Spam!Spam!Spam!Spam!Spam!Spam!'

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %% [markdown]
# Testing

# %%
import os
os.getcwd()
# Out:
# 'D:\\A_Learning\\Python\\Learning_Python'

# %% [markdown]
# Entering multiline statements

# %%
for x in 'spam':
    print(x)
# Out:
# s
# p
# a
# m

# %%
for x in 'spam':
    print(x)
print('done')
# Out:
# s
# p
# a
# m
# done

# %% [markdown]
# System Command Lines and Files

# %%
import sys
print(sys.platform)   # load a library module
# Out:
# win32

# %%
print(2 * 100)       # raise 2 to a power
# Out:
# 200

# %%
x = 'Spam'
print(x * 8)         # string repetition
# Out:
# SpamSpamSpamSpamSpamSpamSpamSpam

# %%
print('The Bright Side' + 'of Life...')  # + means concatenation for strings
# Out:
# The Bright Sideof Life...

# %%
input()     # <== ADDED, reads the next line  of standard input
# Out:
# a
# 'a'
